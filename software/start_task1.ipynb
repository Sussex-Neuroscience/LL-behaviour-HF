# %%
%serialconnect to --port=/dev/com4 --baud=115200
# Out:
# Connecting to --port=/dev/ttyUSB0 --baud=115200
# Ready.

# %%
#%sendtofile --source="tasks.py" "tasks.py"
#%rebootdevice

# %%
#import servo
import tasks

# %%
#set testing to 1 if you need to run things faster for testing purposes
#task = tasks.Task1(testing=1)
task = tasks.Task1(testing=0)

# %%
task.moveBackDelay = 700

# %%
#test solenoids 
task.solenoid1()

# %%
task.solenoid2()

# %%
#range of movement of the servo motors
#maximal max value 65
#minimum min value 25
task.servoMax = 43
task.servoMin = 26

#move servos forward
task.move_servos_forward()

# %%
task.move_servos_backward()

# %%
task.reward2Duration = 130
task.reward1Duration = 130

# %%
task.run_task1()
# Out:
# status: 3
#
# trial 1
# bias correction
# monitor: 1
#
# ..stim on
# ..moving servos
# lick spout 1 error
#
# trials = 1
# no lick = 0
# correct trials = 0
# incorrect trials = 1
#
# lick spout 1 correct = 0
# lick spout 2 correct = 0
#
# lick spout 1 incorrect = 1
# lick spout 2 incorrect = 0
#
# ..status: 3
#
# trial 1
# bias correction
# monitor: 1
#
# ..stim on
# ..moving servos
# solenoid2
#
# trials = 1
# no lick = 0
# correct trials = 1
# incorrect trials = 0
#
# lick spout 1 correct = 0
# lick spout 2 correct = 1
#
# lick spout 1 incorrect = 0
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 2
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 2
# no lick = 0
# correct trials = 2
# incorrect trials = 0
#
# lick spout 1 correct = 0
# lick spout 2 correct = 2
#
# lick spout 1 incorrect = 0
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 3
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 3
# no lick = 0
# correct trials = 3
# incorrect trials = 0
#
# lick spout 1 correct = 1
# lick spout 2 correct = 2
#
# lick spout 1 incorrect = 0
# lick spout 2 incorrect = 0
#
# ..status: 1
#
# trial 4
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 4
# no lick = 0
# correct trials = 4
# incorrect trials = 0
#
# lick spout 1 correct = 1
# lick spout 2 correct = 3
#
# lick spout 1 incorrect = 0
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 5
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 5
# no lick = 0
# correct trials = 5
# incorrect trials = 0
#
# lick spout 1 correct = 2
# lick spout 2 correct = 3
#
# lick spout 1 incorrect = 0
# lick spout 2 incorrect = 0
#
# ...status: 1
#
# trial 6
# no correction
# monitor: 1
#
# stim on
# .moving servos
# lick spout 1 error
#
# trials = 6
# no lick = 0
# correct trials = 5
# incorrect trials = 1
#
# lick spout 1 correct = 2
# lick spout 2 correct = 3
#
# lick spout 1 incorrect = 1
# lick spout 2 incorrect = 0
#
# ...status: 3
#
# trial 6
# bias correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 6
# no lick = 0
# correct trials = 6
# incorrect trials = 1
#
# lick spout 1 correct = 2
# lick spout 2 correct = 4
#
# lick spout 1 incorrect = 1
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 7
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# lick spout 1 error
#
# trials = 7
# no lick = 0
# correct trials = 6
# incorrect trials = 2
#
# lick spout 1 correct = 2
# lick spout 2 correct = 4
#
# lick spout 1 incorrect = 2
# lick spout 2 incorrect = 0
#
# ..status: 3
#
# trial 7
# bias correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 7
# no lick = 0
# correct trials = 7
# incorrect trials = 2
#
# lick spout 1 correct = 2
# lick spout 2 correct = 5
#
# lick spout 1 incorrect = 2
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 8
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 8
# no lick = 0
# correct trials = 8
# incorrect trials = 2
#
# lick spout 1 correct = 3
# lick spout 2 correct = 5
#
# lick spout 1 incorrect = 2
# lick spout 2 incorrect = 0
#
# ..status: 1
#
# trial 9
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# lick spout 1 error
#
# trials = 9
# no lick = 0
# correct trials = 8
# incorrect trials = 3
#
# lick spout 1 correct = 3
# lick spout 2 correct = 5
#
# lick spout 1 incorrect = 3
# lick spout 2 incorrect = 0
#
# ..status: 3
#
# trial 9
# bias correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 9
# no lick = 0
# correct trials = 9
# incorrect trials = 3
#
# lick spout 1 correct = 3
# lick spout 2 correct = 6
#
# lick spout 1 incorrect = 3
# lick spout 2 incorrect = 0
#
# ...status: 2
#
# trial 10
# no correction
# monitor: 0
#
# stim on
# .moving servos
# solenoid1
#
# trials = 10
# no lick = 0
# correct trials = 10
# incorrect trials = 3
#
# lick spout 1 correct = 4
# lick spout 2 correct = 6
#
# lick spout 1 incorrect = 3
# lick spout 2 incorrect = 0
#
# ...status: 1
#
# trial 11
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# lick spout 1 error
#
# trials = 11
# no lick = 0
# correct trials = 10
# incorrect trials = 4
#
# lick spout 1 correct = 4
# lick spout 2 correct = 6
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 0
#
# ..status: 3
#
# trial 11
# bias correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 11
# no lick = 0
# correct trials = 11
# incorrect trials = 4
#
# lick spout 1 correct = 4
# lick spout 2 correct = 7
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 12
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 12
# no lick = 0
# correct trials = 12
# incorrect trials = 4
#
# lick spout 1 correct = 4
# lick spout 2 correct = 8
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 13
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 13
# no lick = 0
# correct trials = 13
# incorrect trials = 4
#
# lick spout 1 correct = 4
# lick spout 2 correct = 9
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 14
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 14
# no lick = 0
# correct trials = 14
# incorrect trials = 4
#
# lick spout 1 correct = 4
# lick spout 2 correct = 10
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 0
#
# ...status: 2
#
# trial 15
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 15
# no lick = 0
# correct trials = 15
# incorrect trials = 4
#
# lick spout 1 correct = 4
# lick spout 2 correct = 11
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 16
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 16
# no lick = 0
# correct trials = 16
# incorrect trials = 4
#
# lick spout 1 correct = 4
# lick spout 2 correct = 12
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 17
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 17
# no lick = 0
# correct trials = 17
# incorrect trials = 4
#
# lick spout 1 correct = 4
# lick spout 2 correct = 13
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 18
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 18
# no lick = 0
# correct trials = 18
# incorrect trials = 4
#
# lick spout 1 correct = 4
# lick spout 2 correct = 14
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 0
#
# ..status: 2
#
# trial 19
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# lick spout 2 error
#
# trials = 19
# no lick = 0
# correct trials = 18
# incorrect trials = 5
#
# lick spout 1 correct = 4
# lick spout 2 correct = 14
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 1
#
# ..status: 4
#
# trial 19
# bias correction
# monitor: 0
#
# stim on
# ..moving servos
# lick spout 2 error
#
# trials = 19
# no lick = 0
# correct trials = 18
# incorrect trials = 6
#
# lick spout 1 correct = 4
# lick spout 2 correct = 14
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 2
#
# ..status: 4
#
# trial 19
# bias correction
# monitor: 0
#
# stim on
# ..moving servos
# lick spout 2 error
#
# trials = 19
# no lick = 0
# correct trials = 18
# incorrect trials = 7
#
# lick spout 1 correct = 4
# lick spout 2 correct = 14
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 3
#
# ..status: 4
#
# trial 19
# bias correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 19
# no lick = 0
# correct trials = 19
# incorrect trials = 7
#
# lick spout 1 correct = 5
# lick spout 2 correct = 14
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 3
#
# ...status: 1
#
# trial 20
# no correction
# monitor: 1
#
# stim on
# .moving servos
# solenoid2
#
# trials = 20
# no lick = 0
# correct trials = 20
# incorrect trials = 7
#
# lick spout 1 correct = 5
# lick spout 2 correct = 15
#
# lick spout 1 incorrect = 4
# lick spout 2 incorrect = 3
#
# ...status: 2
#
# trial 21
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# lick spout 1 error
#
# trials = 21
# no lick = 0
# correct trials = 20
# incorrect trials = 8
#
# lick spout 1 correct = 5
# lick spout 2 correct = 15
#
# lick spout 1 incorrect = 5
# lick spout 2 incorrect = 3
#
# ..status: 3
#
# trial 21
# bias correction
# monitor: 1
#
# stim on
# ..moving servos
# lick spout 1 error
#
# trials = 21
# no lick = 0
# correct trials = 20
# incorrect trials = 9
#
# lick spout 1 correct = 5
# lick spout 2 correct = 15
#
# lick spout 1 incorrect = 6
# lick spout 2 incorrect = 3
#
# ..status: 3
#
# trial 21
# bias correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 21
# no lick = 0
# correct trials = 21
# incorrect trials = 9
#
# lick spout 1 correct = 5
# lick spout 2 correct = 16
#
# lick spout 1 incorrect = 6
# lick spout 2 incorrect = 3
#
# ..status: 2
#
# trial 22
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 22
# no lick = 0
# correct trials = 22
# incorrect trials = 9
#
# lick spout 1 correct = 6
# lick spout 2 correct = 16
#
# lick spout 1 incorrect = 6
# lick spout 2 incorrect = 3
#
# ..status: 1
#
# trial 23
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 23
# no lick = 0
# correct trials = 23
# incorrect trials = 9
#
# lick spout 1 correct = 7
# lick spout 2 correct = 16
#
# lick spout 1 incorrect = 6
# lick spout 2 incorrect = 3
#
# ..status: 1
#
# trial 24
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 24
# no lick = 0
# correct trials = 24
# incorrect trials = 9
#
# lick spout 1 correct = 8
# lick spout 2 correct = 16
#
# lick spout 1 incorrect = 6
# lick spout 2 incorrect = 3
#
# ..status: 1
#
# trial 25
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 25
# no lick = 0
# correct trials = 25
# incorrect trials = 9
#
# lick spout 1 correct = 9
# lick spout 2 correct = 16
#
# lick spout 1 incorrect = 6
# lick spout 2 incorrect = 3
#
# ..status: 1
#
# trial 26
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# lick spout 1 error
#
# trials = 26
# no lick = 0
# correct trials = 25
# incorrect trials = 10
#
# lick spout 1 correct = 9
# lick spout 2 correct = 16
#
# lick spout 1 incorrect = 7
# lick spout 2 incorrect = 3
#
# ..status: 3
#
# trial 26
# bias correction
# monitor: 1
#
# stim on
# ..moving servos
# lick spout 1 error
#
# trials = 26
# no lick = 0
# correct trials = 25
# incorrect trials = 11
#
# lick spout 1 correct = 9
# lick spout 2 correct = 16
#
# lick spout 1 incorrect = 8
# lick spout 2 incorrect = 3
#
# ...status: 3
#
# trial 26
# bias correction
# monitor: 1
#
# stim on
# .moving servos
# .lick spout 1 error
#
# trials = 26
# no lick = 0
# correct trials = 25
# incorrect trials = 12
#
# lick spout 1 correct = 9
# lick spout 2 correct = 16
#
# lick spout 1 incorrect = 9
# lick spout 2 incorrect = 3
#
# ..status: 3
#
# trial 26
# bias correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 26
# no lick = 0
# correct trials = 26
# incorrect trials = 12
#
# lick spout 1 correct = 9
# lick spout 2 correct = 17
#
# lick spout 1 incorrect = 9
# lick spout 2 incorrect = 3
#
# ..status: 2
#
# trial 27
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 27
# no lick = 0
# correct trials = 27
# incorrect trials = 12
#
# lick spout 1 correct = 10
# lick spout 2 correct = 17
#
# lick spout 1 incorrect = 9
# lick spout 2 incorrect = 3
#
# ..status: 1
#
# trial 28
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 28
# no lick = 0
# correct trials = 28
# incorrect trials = 12
#
# lick spout 1 correct = 11
# lick spout 2 correct = 17
#
# lick spout 1 incorrect = 9
# lick spout 2 incorrect = 3
#
# ..status: 1
#
# trial 29
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 29
# no lick = 0
# correct trials = 29
# incorrect trials = 12
#
# lick spout 1 correct = 11
# lick spout 2 correct = 18
#
# lick spout 1 incorrect = 9
# lick spout 2 incorrect = 3
#
# ..status: 2
#
# trial 30
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 30
# no lick = 0
# correct trials = 30
# incorrect trials = 12
#
# lick spout 1 correct = 12
# lick spout 2 correct = 18
#
# lick spout 1 incorrect = 9
# lick spout 2 incorrect = 3
#
# ..status: 1
#
# trial 31
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 31
# no lick = 0
# correct trials = 31
# incorrect trials = 12
#
# lick spout 1 correct = 13
# lick spout 2 correct = 18
#
# lick spout 1 incorrect = 9
# lick spout 2 incorrect = 3
#
# ..status: 1
#
# trial 32
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 32
# no lick = 0
# correct trials = 32
# incorrect trials = 12
#
# lick spout 1 correct = 14
# lick spout 2 correct = 18
#
# lick spout 1 incorrect = 9
# lick spout 2 incorrect = 3
#
# ..status: 1
#
# trial 33
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# lick spout 1 error
#
# trials = 33
# no lick = 0
# correct trials = 32
# incorrect trials = 13
#
# lick spout 1 correct = 14
# lick spout 2 correct = 18
#
# lick spout 1 incorrect = 10
# lick spout 2 incorrect = 3
#
# ...status: 3
#
# trial 33
# bias correction
# monitor: 1
#
# stim on
# .moving servos
# lick spout 1 error
#
# trials = 33
# no lick = 0
# correct trials = 32
# incorrect trials = 14
#
# lick spout 1 correct = 14
# lick spout 2 correct = 18
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 3
#
# ...status: 3
#
# trial 33
# bias correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 33
# no lick = 0
# correct trials = 33
# incorrect trials = 14
#
# lick spout 1 correct = 14
# lick spout 2 correct = 19
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 3
#
# ..status: 2
#
# trial 34
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# lick spout 2 error
#
# trials = 34
# no lick = 0
# correct trials = 33
# incorrect trials = 15
#
# lick spout 1 correct = 14
# lick spout 2 correct = 19
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 4
#
# ..status: 4
#
# trial 34
# bias correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 34
# no lick = 0
# correct trials = 34
# incorrect trials = 15
#
# lick spout 1 correct = 15
# lick spout 2 correct = 19
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 4
#
# ..status: 1
#
# trial 35
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 35
# no lick = 0
# correct trials = 35
# incorrect trials = 15
#
# lick spout 1 correct = 16
# lick spout 2 correct = 19
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 4
#
# ..status: 1
#
# trial 36
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 36
# no lick = 0
# correct trials = 36
# incorrect trials = 15
#
# lick spout 1 correct = 16
# lick spout 2 correct = 20
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 4
#
# ..status: 2
#
# trial 37
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 37
# no lick = 0
# correct trials = 37
# incorrect trials = 15
#
# lick spout 1 correct = 16
# lick spout 2 correct = 21
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 4
#
# ..status: 2
#
# trial 38
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 38
# no lick = 0
# correct trials = 38
# incorrect trials = 15
#
# lick spout 1 correct = 17
# lick spout 2 correct = 21
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 4
#
# ..status: 1
#
# trial 39
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 39
# no lick = 0
# correct trials = 39
# incorrect trials = 15
#
# lick spout 1 correct = 18
# lick spout 2 correct = 21
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 4
#
# ..status: 1
#
# trial 40
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 40
# no lick = 0
# correct trials = 40
# incorrect trials = 15
#
# lick spout 1 correct = 19
# lick spout 2 correct = 21
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 4
#
# ...status: 1
#
# trial 41
# no correction
# monitor: 1
#
# stim on
# .moving servos
# solenoid2
#
# trials = 41
# no lick = 0
# correct trials = 41
# incorrect trials = 15
#
# lick spout 1 correct = 19
# lick spout 2 correct = 22
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 4
#
# ...status: 2
#
# trial 42
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 42
# no lick = 0
# correct trials = 42
# incorrect trials = 15
#
# lick spout 1 correct = 19
# lick spout 2 correct = 23
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 4
#
# ..status: 2
#
# trial 43
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# lick spout 2 error
#
# trials = 43
# no lick = 0
# correct trials = 42
# incorrect trials = 16
#
# lick spout 1 correct = 19
# lick spout 2 correct = 23
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 5
#
# ..status: 4
#
# trial 43
# bias correction
# monitor: 0
#
# stim on
# ..moving servos
# no licks
# trials = 43
# no lick = 1
# correct trials = 42
# incorrect trials = 16
#
# lick spout 1 correct = 19
# lick spout 2 correct = 23
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 5
#
# ..status: 0
#
# trial 44
# no correction
# monitor: 0
#
# stim on
# ..moving servos
# lick spout 2 error
#
# trials = 44
# no lick = 1
# correct trials = 42
# incorrect trials = 17
#
# lick spout 1 correct = 19
# lick spout 2 correct = 23
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 6
#
# ..status: 4
#
# trial 44
# bias correction
# monitor: 0
#
# stim on
# ..moving servos
# solenoid1
#
# trials = 44
# no lick = 1
# correct trials = 43
# incorrect trials = 17
#
# lick spout 1 correct = 20
# lick spout 2 correct = 23
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 6
#
# ...status: 1
#
# trial 45
# no correction
# monitor: 1
#
# stim on
# .moving servos
# solenoid2
#
# trials = 45
# no lick = 1
# correct trials = 44
# incorrect trials = 17
#
# lick spout 1 correct = 20
# lick spout 2 correct = 24
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 6
#
# ...status: 2
#
# trial 46
# no correction
# monitor: 1
#
# stim on
# ..moving servos
# solenoid2
#
# trials = 46
# no lick = 1
# correct trials = 45
# incorrect trials = 17
#
# lick spout 1 correct = 20
# lick spout 2 correct = 25
#
# lick spout 1 incorrect = 11
# lick spout 2 incorrect = 6
#
#
#
# *** Sending Ctrl-C
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
#   File "tasks.py", line 337, in run_task1
#   File "tasks.py", line 411, in time_intervals
# KeyboardInterrupt:
